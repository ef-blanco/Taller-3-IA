# %% [markdown]
# # Parte 2: Transformación a CNF y Resolución
#
# En esta parte implementarás las transformaciones necesarias para convertir fórmulas a **Forma Normal Conjuntiva (CNF)**, y luego usarás el algoritmo de resolución (dado) para probar implicaciones.
#
# ## ¿Qué es CNF?
#
# Una fórmula está en CNF si es una conjunción (∧) de cláusulas, donde cada cláusula es una disyunción (∨) de literales.
#
# **Ejemplo:** `(p ∨ ¬q) ∧ (¬p ∨ r ∨ s) ∧ (q)`
#
# ## Pipeline de conversión a CNF
#
# 1. Eliminar bicondicionales (↔) → **TÚ**
# 2. Eliminar implicaciones (→) → **TÚ**
# 3. Mover negaciones hacia adentro (De Morgan) → **TÚ**
# 4. Eliminar dobles negaciones (¬¬) → **DADO**
# 5. Distribuir ∨ sobre ∧ → **TÚ**
# 6. Aplanar → **TÚ**

# %%
import sys
sys.path.insert(0, '..')

from src.logic_core import Atom, Not, And, Or, Implies, Iff
from src.utils import formula_to_string

# %% [markdown]
# ## Paso 1: Eliminar Bicondicionales
#
# **Regla:** `A ↔ B` ≡ `(A → B) ∧ (B → A)`
#
# Implementa `eliminate_iff` en `src/cnf_transform.py`.

# %%
from src.cnf_transform import eliminate_iff

f = Iff(Atom('p'), Atom('q'))
result = eliminate_iff(f)
print(f"Original: {formula_to_string(f)}")
print(f"Sin ↔:    {formula_to_string(result)}")
# Out:
# Original: (p ↔ q)
# Sin ↔:    ((p → q) ∧ (q → p))

# %% [markdown]
# ## Paso 2: Eliminar Implicaciones
#
# **Regla:** `A → B` ≡ `¬A ∨ B`
#
# Implementa `eliminate_implication` en `src/cnf_transform.py`.

# %%
from src.cnf_transform import eliminate_implication

f = Implies(Atom('p'), Atom('q'))
result = eliminate_implication(f)
print(f"Original: {formula_to_string(f)}")
print(f"Sin →:    {formula_to_string(result)}")
# Out:
# Original: (p → q)
# Sin →:    (¬p ∨ q)

# %% [markdown]
# ## Paso 3: Mover Negaciones hacia Adentro (De Morgan)
#
# **Reglas:**
# - `¬(A ∧ B)` ≡ `¬A ∨ ¬B`
# - `¬(A ∨ B)` ≡ `¬A ∧ ¬B`
#
# Implementa `push_negation_inward` en `src/cnf_transform.py`.

# %%
from src.cnf_transform import push_negation_inward

# De Morgan sobre And
f1 = Not(And(Atom('p'), Atom('q')))
r1 = push_negation_inward(f1)
print(f"¬(p ∧ q):  {formula_to_string(f1)}")
print(f"De Morgan: {formula_to_string(r1)}")

print()

# De Morgan sobre Or
f2 = Not(Or(Atom('p'), Atom('q')))
r2 = push_negation_inward(f2)
print(f"¬(p ∨ q):  {formula_to_string(f2)}")
print(f"De Morgan: {formula_to_string(r2)}")
# Out:
# ¬(p ∧ q):  ¬(p ∧ q)
# De Morgan: (¬p ∨ ¬q)
#
# ¬(p ∨ q):  ¬(p ∨ q)
# De Morgan: (¬p ∧ ¬q)

# %% [markdown]
# ## Paso 4: Eliminar Dobles Negaciones (DADO)
#
# **Regla:** `¬¬A` ≡ `A`
#
# Esta función ya está implementada. Puedes estudiarla como referencia para las demás.

# %%
from src.cnf_transform import eliminate_double_negation

f = Not(Not(Atom('p')))
result = eliminate_double_negation(f)
print(f"Original: {formula_to_string(f)}")
print(f"Sin ¬¬:   {formula_to_string(result)}")
# Out:
# Original: ¬¬p
# Sin ¬¬:   p

# %% [markdown]
# ## Paso 5: Distribuir ∨ sobre ∧
#
# **Regla:** `A ∨ (B ∧ C)` ≡ `(A ∨ B) ∧ (A ∨ C)`
#
# Esta es la transformación clave para obtener CNF: cada ∨ que contenga un ∧ adentro se "reparte".
#
# Implementa `distribute_or_over_and` en `src/cnf_transform.py`.

# %%
from src.cnf_transform import distribute_or_over_and

# p ∨ (q ∧ r) → (p ∨ q) ∧ (p ∨ r)
f = Or(Atom('p'), And(Atom('q'), Atom('r')))
result = distribute_or_over_and(f)
print(f"Original:    {formula_to_string(f)}")
print(f"Distribuido: {formula_to_string(result)}")
# Out:
# Original:    (p ∨ (q ∧ r))
# Distribuido: ((q ∨ p) ∧ (r ∨ p))

# %% [markdown]
# ## Paso 6: Aplanar
#
# **Reglas:**
# - `(A ∧ B) ∧ C` ≡ `A ∧ B ∧ C`
# - `(A ∨ B) ∨ C` ≡ `A ∨ B ∨ C`
#
# El último paso: eliminar anidamientos innecesarios para obtener una CNF limpia.
#
# Implementa `flatten` en `src/cnf_transform.py`.

# %%
from src.cnf_transform import flatten

# And(And(a, b), c) → And(a, b, c)
f = And(And(Atom('a'), Atom('b')), Atom('c'))
result = flatten(f)
print(f"Original:  {formula_to_string(f)}")
print(f"Aplanado:  {formula_to_string(result)}")
# Out:
# Original:  ((a ∧ b) ∧ c)
# Aplanado:  (a ∧ b ∧ c)

# %% [markdown]
# ## Pipeline completo: `to_cnf`
#
# Una vez implementadas tus 5 funciones, el pipeline completo debería funcionar.

# %%
from src.cnf_transform import to_cnf

# p → (q ∧ r) debería dar (¬p ∨ q) ∧ (¬p ∨ r)
f = Implies(Atom('p'), And(Atom('q'), Atom('r')))
cnf = to_cnf(f)
print(f"Original: {formula_to_string(f)}")
print(f"CNF:      {formula_to_string(cnf)}")
# Out:
# Original: (p → (q ∧ r))
# CNF:      ((q ∨ ¬p) ∧ (r ∨ ¬p))

# %% [markdown]
# ## Verificar con Resolución
#
# Usa el módulo de resolución (dado) para probar que tus transformaciones son correctas.

# %%
from src.resolution import resolution_prove

# Probar modus ponens: {p → q, p} ⊢ q
kb = [Implies(Atom('p'), Atom('q')), Atom('p')]
proved, steps = resolution_prove(kb, Atom('q'))
print(f"¿Probado? {proved}")
print("\nPasos:")
for step in steps:
    print(step)
# Out:
# ¿Probado? True
#
# Pasos:
#   KB: {q, ~p}
#   KB: {p}
#   ¬Query: {~q}
# --- Inicio de resolución ---
#   Resolviendo {p} con {q, ~p} → {q}
#   Resolviendo {~q} con {q, ~p} → {~p}
#   Resolviendo {q} con {~q} → □ (vacía)
#   ¡Cláusula vacía derivada! QED.

# %%
# Probar con el caso criminal
kb_criminal = [
    Implies(Not(Atom('llovía')), Not(Atom('jardín_mojado'))),
    Atom('jardín_mojado'),
]

proved, steps = resolution_prove(kb_criminal, Atom('llovía'))
print(f"¿Llovía? {proved}")
print("\nPasos:")
for step in steps:
    print(step)
# Out:
# ¿Llovía? True
#
# Pasos:
#   KB: {llovía, ~jardín_mojado}
#   KB: {jardín_mojado}
#   ¬Query: {~llovía}
# --- Inicio de resolución ---
#   Resolviendo {llovía, ~jardín_mojado} con {~llovía} → {~jardín_mojado}
#   Resolviendo {llovía, ~jardín_mojado} con {jardín_mojado} → {llovía}
#   Resolviendo {llovía, ~jardín_mojado} con {jardín_mojado} → {llovía}
#   Resolviendo {llovía, ~jardín_mojado} con {~llovía} → {~jardín_mojado}
#   Resolviendo {jardín_mojado} con {~jardín_mojado} → □ (vacía)
#   ¡Cláusula vacía derivada! QED.

# %%
# !cd .. && python -m pytest tests/test_cnf.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.5, pytest-8.3.4, pluggy-1.5.0 -- c:\Users\pifbl\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\pifbl\Documents\Uniandes\Inteligencia Artificial\Taller_3\Clue
# configfile: pyproject.toml
# plugins: anyio-4.7.0, typeguard-4.4.4
# collecting ... collected 44 items
#
# tests/test_cnf.py::TestEliminateIff::test_simple_iff PASSED              [  2%]
# tests/test_cnf.py::TestEliminateIff::test_nested_iff PASSED              [  4%]
# tests/test_cnf.py::TestEliminateIff::test_no_iff PASSED                  [  6%]
# tests/test_cnf.py::TestEliminateIff::test_iff_inside_not PASSED          [  9%]
# tests/test_cnf.py::TestEliminateIff::test_iff_inside_and PASSED          [ 11%]
# tests/test_cnf.py::TestEliminateImplication::test_simple_implication PASSED [ 13%]
# tests/test_cnf.py::TestEliminateImplication::test_nested_implication PASSED [ 15%]
# tests/test_cnf.py::TestEliminateImplication::test_no_implication PASSED  [ 18%]
# tests/test_cnf.py::TestEliminateImplication::test_implication_in_and PASSED [ 20%]
# tests/test_cnf.py::TestPushNegationInward::test_de_morgan_and PASSED     [ 22%]
# tests/test_cnf.py::TestPushNegationInward::test_de_morgan_or PASSED      [ 25%]
# tests/test_cnf.py::TestPushNegationInward::test_no_negation PASSED       [ 27%]
# tests/test_cnf.py::TestPushNegationInward::test_nested_de_morgan PASSED  [ 29%]
# tests/test_cnf.py::TestPushNegationInward::test_deeply_nested PASSED     [ 31%]
# tests/test_cnf.py::TestPushNegationInward::test_nary_de_morgan PASSED    [ 34%]
# tests/test_cnf.py::TestDistributeOrOverAnd::test_simple_distribution PASSED [ 36%]
# tests/test_cnf.py::TestDistributeOrOverAnd::test_no_distribution_needed PASSED [ 38%]
# tests/test_cnf.py::TestDistributeOrOverAnd::test_and_stays PASSED        [ 40%]
# tests/test_cnf.py::TestDistributeOrOverAnd::test_nested_distribution PASSED [ 43%]
# tests/test_cnf.py::TestDistributeOrOverAnd::test_both_sides_and PASSED   [ 45%]
# tests/test_cnf.py::TestDistributeOrOverAnd::test_or_with_multiple_and_children PASSED [ 47%]
# tests/test_cnf.py::TestFlatten::test_flatten_and PASSED                  [ 50%]
# tests/test_cnf.py::TestFlatten::test_flatten_or PASSED                   [ 52%]
# tests/test_cnf.py::TestFlatten::test_no_flatten_needed PASSED            [ 54%]
# tests/test_cnf.py::TestFlatten::test_deep_nesting PASSED                 [ 56%]
# tests/test_cnf.py::TestFlatten::test_mixed_nesting PASSED                [ 59%]
# tests/test_cnf.py::TestFlatten::test_single_element_after_flatten PASSED [ 61%]
# tests/test_cnf.py::TestFlatten::test_flatten_not PASSED                  [ 63%]
# tests/test_cnf.py::TestEliminateDoubleNegation::test_double_negation PASSED [ 65%]
# tests/test_cnf.py::TestEliminateDoubleNegation::test_triple_negation PASSED [ 68%]
# tests/test_cnf.py::TestEliminateDoubleNegation::test_no_double_negation PASSED [ 70%]
# tests/test_cnf.py::TestEliminateDoubleNegation::test_nested_double_negation PASSED [ 72%]
# tests/test_cnf.py::TestToCNF::test_simple_implication PASSED             [ 75%]
# tests/test_cnf.py::TestToCNF::test_distribute_or_over_and PASSED         [ 77%]
# tests/test_cnf.py::TestToCNF::test_de_morgan PASSED                      [ 79%]
# tests/test_cnf.py::TestToCNF::test_complex_formula PASSED                [ 81%]
# tests/test_cnf.py::TestToCNF::test_biconditional PASSED                  [ 84%]
# tests/test_cnf.py::TestToCNF::test_complex_nested PASSED                 [ 86%]
# tests/test_cnf.py::TestToCNF::test_nested_biconditional_chain FAILED     [ 88%]
# tests/test_cnf.py::TestToCNF::test_four_variables_complex PASSED         [ 90%]
# tests/test_cnf.py::TestToCNF::test_double_negation_inside_iff PASSED     [ 93%]
# tests/test_cnf.py::TestToCNF::test_criminal_case_knowledge PASSED        [ 95%]
# tests/test_cnf.py::TestToCNF::test_mutual_alibi_structure PASSED         [ 97%]
# tests/test_cnf.py::TestToCNF::test_or_of_three_conjunctions PASSED       [100%]
#
# ================================== FAILURES ===================================
# __________________ TestToCNF.test_nested_biconditional_chain __________________
#
# self = <tests.test_cnf.TestToCNF object at 0x000002EDB6EEA030>
#
#     def test_nested_biconditional_chain(self):
#         """Iff(p, Iff(q, r)) — bicondicional anidado con 3 variables."""
#         formula = Iff(Atom("p"), Iff(Atom("q"), Atom("r")))
#         cnf = to_cnf(formula)
#         assert _is_equivalent(formula, cnf)
# >       assert _is_cnf(cnf)
# E       AssertionError: assert False
# E        +  where False = _is_cnf(And(Or(Not(Atom('q')), Atom('r'), Not(Atom('p'))), Or(Not(Atom('r')), Atom('q'), Not(Atom('p'))), Or(And(Or(Atom('q'), Atom('r')), Or(Atom('q'), Not(Atom('q'))), Or(Not(Atom('r')), Atom('r')), Or(Not(Atom('r')), Not(Atom('q'))), Or(Atom('r'), Atom('q')), Or(Atom('r'), Not(Atom('r'))), Or(Not(Atom('q')), Atom('q')), Or(Not(Atom('q')), Not(Atom('r')))), Atom('p'))))
#
# tests\test_cnf.py:309: AssertionError
# =========================== short test summary info ===========================
# FAILED tests/test_cnf.py::TestToCNF::test_nested_biconditional_chain - AssertionError: assert False
# ======================== 1 failed, 43 passed in 0.14s =========================
